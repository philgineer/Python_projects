# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import cv2

# %%
img = cv2.imread('D:/python/udemy_cv/00-puppy.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img2 = cv2.imread('wrong/path/not_exist.jpg')

# %%
type(img2)
# Out:
# NoneType

# %%
img.shape
# Out:
# (1300, 1950, 3)

# %%
img
# Out:
# array([[[78, 81, 95],
#         [80, 83, 97],
#         [81, 84, 98],
#         ...,
#         [22, 27, 25],
#         [22, 27, 25],
#         [22, 27, 25]],
#
#        [[78, 81, 95],
#         [79, 82, 96],
#         [79, 82, 96],
#         ...,
#         [22, 27, 25],
#         [22, 27, 25],
#         [22, 27, 25]],
#
#        [[78, 81, 95],
#         [77, 80, 94],
#         [77, 80, 94],
#         ...,
#         [22, 27, 25],
#         [22, 27, 25],
#         [22, 27, 25]],
#
#        ...,
#
#        [[20, 29, 19],
#         [21, 30, 20],
#         [21, 30, 20],
#         ...,
#         [22, 30, 23],
#         [23, 31, 24],
#         [23, 31, 24]],
#
#        [[21, 30, 20],
#         [21, 30, 20],
#         [20, 29, 19],
#         ...,
#         [22, 30, 23],
#         [23, 31, 24],
#         [23, 31, 24]],
#
#        [[21, 30, 20],
#         [20, 29, 19],
#         [20, 29, 19],
#         ...,
#         [22, 30, 23],
#         [23, 31, 24],
#         [23, 31, 24]]], dtype=uint8)

# %%
plt.imshow(img)

# %%
# matplotlib: R G B
# opencv : B G R

# %%
fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(fix_img)

# %%
img_gray = cv2.imread('D:/python/udemy_cv/00-puppy.jpg', cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape
# Out:
# (1300, 1950)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
new_img = cv2.resize(fix_img, (1000, 400))
plt.imshow(new_img)

# %%
w_ratio = 0.3
h_ratio = 0.7

new_img = cv2.resize(fix_img, (0,0), fix_img, w_ratio, h_ratio)
new_img = cv2.flip(new_img, -1)
plt.imshow(new_img)

# %%
type(new_img)
# Out:
# numpy.ndarray

# %%
cv2.imwrite('00-new_puppy.jpg', new_img)
# Out:
# True

# %%
fig = plt.figure(figsize=(2,2))
ax = fig.add_subplot(111)
ax.imshow(new_img)

# %% [markdown]
# ### opening file with opencv

# %%
cv2.imshow('puppy', img)
cv2.waitKey()
# Out:
# -1
