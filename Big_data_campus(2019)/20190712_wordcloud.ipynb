# %% [markdown]
# ## wordcloud

# %%
import requests, operator, pandas, glob2
from bs4 import BeautifulSoup
from datetime import datetime

# %%
import nltk
from konlpy.tag import Twitter
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="C:/Windows/Fonts/gulim.ttc").get_name()
rc('font', family=font_name)

from wordcloud import WordCloud
import matplotlib.pyplot as plt

t=Twitter()
# Out:
# C:\ProgramData\Anaconda3\envs\python_edu\lib\site-packages\konlpy\tag\_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %%
def analyze(content):
    nouns = t.nouns(str(content))
    
    trash = ["조선", "연합뉴스", "일보", "중앙", "기자", "뉴스", "헤럴드경제"]
    for i in trash:
        for j in nouns:
            if i==j:
                nouns.remove(i)
                
    ko = nltk.Text(nouns, name="분석")
    
    ranking = ko.vocab().most_common(100)
    tmpData = dict(ranking)
    
    wordcloud = WordCloud(font_path = "C:/Windows/Fonts/gulim.ttc",
                         relative_scaling=0.2, background_color="white").generate_from_frequencies(tmpData)
    
    plt.figure(figsize=(20,10))
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.show()

# %%
analyze(a)

# %%
b = pandas.read_csv("2019-7-12-16-23-30 merging.csv")

# %%
b.head()
# Out:
#    Unnamed: 0 Company                                            Content  \
# 0           0    연합뉴스  (서울=연합뉴스) 정연식기자 = 새 천년을 하루 앞둔 31일 북한의 조선중앙TV는 ...
# 1           1    연합뉴스  (서울=연합뉴스) 염주인기자 = 김대중(金大中) 대통령은 31일 밤 부인 이희호(李...
# 2           2    연합뉴스  (서울=연합뉴스) 심규석기자 = 새 천년을 맞으며 평양시 곳곳에서는 다양한 체육경기...
# 3           3    연합뉴스  (서울=연합뉴스) ▲김정일 노동당 총비서와 김영남 최고인민회의 상임위원장은 지난 2...
# 4           4    연합뉴스  (서울=연합뉴스) 심규석기자 = 북한은 재일 조총련의 민족권리 옹호를 위한 활동 등...
#
#                    Date LinkSrc Title    imgSrc
# 0  1999.12.31. 오후 11:15    None  None  No image
# 1  1999.12.31. 오후 11:00    None  None  No image
# 2  1999.12.31. 오후 10:42    None  None  No image
# 3  1999.12.31. 오후 10:40    None  None  No image
# 4   1999.12.31. 오후 9:55    None  None  No image

# %%
str(b['Content'])
# Out:
# "0       (서울=연합뉴스) 정연식기자 = 새 천년을 하루 앞둔 31일 북한의 조선중앙TV는 ...\n1       (서울=연합뉴스) 염주인기자 = 김대중(金大中) 대통령은 31일 밤 부인 이희호(李...\n2       (서울=연합뉴스) 심규석기자 = 새 천년을 맞으며 평양시 곳곳에서는 다양한 체육경기...\n3       (서울=연합뉴스) ▲김정일 노동당 총비서와 김영남 최고인민회의 상임위원장은 지난 2...\n4       (서울=연합뉴스) 심규석기자 = 북한은 재일 조총련의 민족권리 옹호를 위한 활동 등...\n5       (서울=연합뉴스) 심규석기자 = 평양 대성산 기슭에 위치한 중앙동물원은 국제적으로 ...\n6       (서울=연합뉴스) 주용성기자 = 올해 3년으로 들어서는 북한 김정일(金正日) 국방위...\n7       (서울=연합뉴스) 김상환기자= 국민의 정부가 올 대북정책에서 거둔 가장 큰 성과는 ...\n8       (서울=연합뉴스) 김현재기자 = 김대중(金大中) 대통령은 31일 폭풍으로 인해 극심...\n9       (서울=연합뉴스) 맹찬형기자 = 중앙선거관리위원회(위원장 이용훈.李容勳)는 1백여일...\n10      (서울=연합뉴스) 김병수기자= 한나라당은 오는 6일부터 10일까지 제16대 국회의원...\n11      (서울=연합뉴스) 김귀근기자 = 국방부의 2000년 국방정책 추진 방향은 선진 국방...\n12      (서울=연합뉴스) 황재훈기자 = 정부와 여당은 1일 의문사 진상규명 특별법이 국회를...\n13      (서울=연합뉴스) 심규석기자 = 북한에서는 올 한해 동안 상표와 공업도안 등 산업미...\n14      (서울=연합뉴스) 최선영기자 = 북한은 31일 미국의 대(對) 러시아 식량원조가 내...\n15      (서울=연합뉴스) 김병수기자= 한나라당 이회창(李會昌) 총재는 31일 오후 세종로 ...\n16      (서울=연합뉴스) 김홍태기자= 국민회의 이만섭(李萬燮) 총재권한대행은 31일 라디
# ...

# %%
analyze(b)

# %% [markdown]
# ## 연습

# %%
a = pandas.read_csv("./1.txt")

# %%
# t.nouns 명사만 추출해서 리스트로 만들어서 리턴. (형용사의 경우 함수 직접 만들어서 써야함)
content = a
nouns = t.nouns(str(content))
nouns
# Out:
# ['승용차',
#  '세단',
#  '통',
#  '국내',
#  '완성',
#  '차',
#  '시장',
#  '중심',
#  '승용',
#  '판매량',
#  '늘',
#  '국내',
#  '등록',
#  '승용차',
#  '중',
#  '차지',
#  '비중',
#  '지난해',
#  '로',
#  '현대차',
#  '기아차',
#  '쌍용차',
#  '르노',
#  '삼성',
#  '한국',
#  '등',
#  '국내',
#  '완성',
#  '차',
#  '개사',
#  '신차',
#  '판매량',
#  '기준',
#  '비중',
#  '지난해',
#  '를',
#  '올해',
#  '상반기',
#  '를',
#  '기록',
#  '것',
#  '집계',
#  '올해',
#  '지금',
#  '승용차',
#  '중',
#  '대가',
#  '뜻',
#  '판매량',
#  '지난',
#  '기록',
#  '지난해',
#  '비교',
#  '증가',
#  '것',
#  '세단',
#  '판매',
#  '줄',
#  '올해',
#  '지난',
#  '국내',
#  '완성',
#  '차',
#  '개사',
#  '승용',
#  '세단',
#  '판',
#  '로',
#  '대로',
#  '못',
#  '국내',
#  '레이',
#  '말리부',
#  '등',
#  '개',
#  '차종',
#  '년',
#  '판매량',
#  '기록',
#  '기간',
#  '총',
#  '개',
#  '팰리세이드',
#  '쏘울',
#  '니',
#  '코란도',
#  '트랙스',
#  '이',
#  '녹스',
#  '개',
#  '차종',
#  '판매',
#  '증가',
#  '것',
#  '대조',
#  '이유',
#  '기술',
#  '발전',
#  '연비',
#  '승',
#  '차감',
#  '때문',
#  '프레임',
#  '무게',
#  '탓',
#  '연비',
#  '실내',
#  '공간',
#  '확보',
#  '모노',
#  '코크',
#  '바디',
# ...

# %%
ko = nltk.Text(nouns, name="분석")

# %%
ko
# Out:
# <Text: 분석>

# %%
ranking = ko.vocab().most_common(10)
ranking
# Out:
# [('국내', 5),
#  ('판매량', 4),
#  ('를', 4),
#  ('차', 4),
#  ('세단', 4),
#  ('기록', 3),
#  ('지난해', 3),
#  ('올해', 3),
#  ('승용차', 3),
#  ('개', 3)]

# %%
tmpData = dict(ranking)
tmpData
# Out:
# {'개': 3,
#  '국내': 5,
#  '기록': 3,
#  '를': 4,
#  '세단': 4,
#  '승용차': 3,
#  '올해': 3,
#  '지난해': 3,
#  '차': 4,
#  '판매량': 4}

# %%
wordcloud = WordCloud(font_path="C:/Windows/Fonts/gulim.ttc").generate_from_frequencies(tmpData)
wordcloud

# %%
plt.figure(figsize=(16,8))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# ## selenium

# %%
from selenium import webdriver
import time

# %%
browser = webdriver.Chrome("C:/python_edu/program/chromedriver.exe")
browser.get("http://python.org")

menus = browser.find_elements_by_css_selector('#top ul.menu li')
# 화면에서 특정 요소 리턴 (스페이스: ~안에. top 안에서 menu 안에서 li)
# 샵(id 속성): top,  ul.(class 속성): menu,  li 태그.  -> 리스트로 리턴


pypi = None  # 이거 없어도 실행 되던데 (local 변수만으로도 되는 건가) 왤까..

for m in menus:
    if m.text == "PyPI":
        pypi = m
    print(m.text)
    
pypi.click()

time.sleep(5)
browser.quit()
# Out:
# Python
# PSF
# Docs
# PyPI
# Jobs
# Community

# %%
menus
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="cc309a194bb1891509e2e170a1503cfa", element="0.8160537923416249-1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cc309a194bb1891509e2e170a1503cfa", element="0.8160537923416249-2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cc309a194bb1891509e2e170a1503cfa", element="0.8160537923416249-3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cc309a194bb1891509e2e170a1503cfa", element="0.8160537923416249-4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cc309a194bb1891509e2e170a1503cfa", element="0.8160537923416249-5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cc309a194bb1891509e2e170a1503cfa", element="0.8160537923416249-6")>]

# %%
pypi
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="aeee1da952fbfb62818029de2340233e", element="0.6004680788269274-4")>

# %%
browser = webdriver.Chrome("C:/python_edu/program/chromedriver.exe")
browser.get("https://nid.naver.com/nidlogin.login?mode=form&url=https%3A%2F%2Fwww.naver.com")

id = browser.find_element_by_css_selector('#id').send_keys("hodolee0420")

time.sleep(1)

pw = browser.find_element_by_css_selector('#pw').send_keys("yunjh9426337")

time.sleep(2)

browser.find_element_by_css_selector('input[class="btn_global"]').click()
